# %% [markdown]
# ## Base model of 6 layers 8 attention heads
# ### Canny edge dataset instead of original dataset
# ### Overfitting occured due to high complexity

# %%
# main.py


import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import os
from PIL import Image
import random
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score, mean_absolute_error

# Define the device (GPU or CPU)
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(device)
################################# Input here ###################################
root_path='/home/zaeemy/zaeem/'
crop='mustard'
csv_file='/home/zaeemy/zaeem/mustard_train.csv'
n_images=4
epochs=10
plant_input=2
days_input=37
batch_size = 8
seed=42
height, width = 224, 224
# Transformations for resizing and converting to tensor
transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()])
##############################################################################

# Set random seeds for reproducibility
def set_seed(seed=42):
    """
    Set random seeds for Python, NumPy, and PyTorch to ensure reproducibility.
    """
    random.seed(seed)  # Python random seed
    np.random.seed(seed)  # Numpy random seed
    torch.manual_seed(seed)  # PyTorch CPU seed
    torch.cuda.manual_seed(seed)  # PyTorch GPU seed (for CUDA)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups

    # Ensure deterministic behavior in CUDA (if using GPU)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Initialize seed for reproducibility
set_seed(42)

num_images = n_images  # Number of images (24 RGB images)
input_channels = num_images*1  # 24 RGB images (3 channels each)
patch_size = 16  # Size of each patch
num_patches = (height // patch_size) * (width // patch_size)  # Number of patches (14 * 14 for 224x224 images)
projection_dim = 256  # Embedding dimension for each patch
num_heads = 8  # Number of attention heads
num_layers = 6  # Number of transformer layers
mlp_dim = 512  # Dimension of the MLP head
num_classes = 1  # Number of output classes (for day or leaf count prediction)
dropout_rate = 0.1  # Dropout rate


class CropDataset(Dataset):
    def __init__(self, root_dir, csv_file, images_per_level, crop, plants, days,
                 levels=['L1', 'L2', 'L3', 'L4', 'L5'], transform=None):
        """
        Args:
            root_dir (str): Directory with all the images.
            csv_file (str): Path to the CSV file containing ground truth (filename, leaf_count, age).
            images_per_level (int): Number of images to select per level (should be factors of 24).
            crop (str): Crop type (e.g., "mustard").
            plants (int): Number of plants (e.g., 4).
            days (int): Number of days (e.g., 59).
            levels (list): List of levels (e.g., ['L1', 'L2', 'L3', 'L4', 'L5']).
            transform (callable, optional): Transform to be applied on a sample.
        """
        self.root_dir = root_dir
        self.csv_file = csv_file
        self.images_per_level = images_per_level
        self.crop = crop
        self.plants_num = plants
        self.max_days = days
        self.levels = levels
        self.transform = transform
        self.image_data = self._load_metadata()
        self.image_paths = self._load_image_paths()

    def _load_metadata(self):
        """Load CSV file into a pandas DataFrame and map filenames to leaf counts and ages."""
        df = pd.read_csv(self.csv_file)
        df["filename"] = df["filename"].astype(str)  # Ensure filenames are strings
        return df.set_index("filename")  # Use filename as the index for quick lookup

    def _select_angles(self):
        """
        Select angles dynamically for a given level.
        """
        images_needed = self.images_per_level
        selected_angles = [i for i in range(0, 360, int(360 / images_needed))]

        initial_angles = [i for i in range(15, selected_angles[1], 15)]
        multiple_selections = [selected_angles]

        for initial_angle in initial_angles:
            selection = [initial_angle]
            while len(selection) < images_needed:
                next_angle = (selection[-1] + int(360 / images_needed)) % 360
                if next_angle not in selection:
                    selection.append(next_angle)
            multiple_selections.append(selection)
        print(f"multiple_selections: {multiple_selections}")
        return multiple_selections

    def _load_image_paths(self):
        """
        Load image paths for all levels and plants based on the selection of angles.
        """
        image_paths = []
        multiple_selections = self._select_angles()

        for plant in range(1, self.plants_num + 1):
            plant_path = os.path.join(self.root_dir, crop, f"p{plant}")
            if not os.path.isdir(plant_path):
                print(f"Plant directory not found: {plant_path}")
                continue
            for day in range(1, self.max_days + 1):
                day_path = os.path.join(self.root_dir, crop, f"p{plant}", f"d{day}")
                if not os.path.isdir(day_path):
                    print(f"day directory not found: {day_path}")
                    continue
                for selected_angles in multiple_selections:
                    for level in self.levels:
                        level_path = os.path.join(self.root_dir,self.crop, f"p{plant}", f"d{day}", level)
                        level_image_paths = [
                            os.path.join(level_path, f"{self.crop}_p{plant}_d{day}_{level}_{angle}.png")
                            for angle in selected_angles
                        ]
                        filename = os.path.join(self.crop,f"p{plant}", f"d{day}", level,f"{self.crop}_p{plant}_d{day}_{level}_{selected_angles[0]}.png")
                        leaf_count = self.image_data.loc[filename, "leaf_count"]
                        # print(level_image_paths)
                        image_paths.append((level_image_paths, leaf_count,day))  # Append day number along with image paths

        print(f"Total samples loaded: {len(image_paths)}")
        # print(f"individual sample size: {len(image_paths[0][0])}")
        return image_paths


    def __len__(self):
        return len(self.image_paths)


    def __getitem__(self, idx):
        """
        Get a batch of images from the dataset corresponding to the angles selected.
        """
        images = []
        leaf_count = self.image_paths[idx][1]
        age = self.image_paths[idx][2]
        # print(leaf_count,age)
        all_images= self.image_paths[idx][0]
        # print("length of all images:", len(all_images))
        for img_path in all_images:  # Get the image paths for this sample
            if os.path.isfile(img_path):
                  level_image = Image.open(img_path)
                  if self.transform:
                      level_image = self.transform(level_image)
                  images.append(level_image)
            else:
                    print(f"Path is not a valid file: {img_path}")

        images = torch.cat(images, dim=0)

        return images, torch.tensor(leaf_count, dtype=torch.float32), torch.tensor(age, dtype=torch.float32)  # Return both images and the corresponding day as ground truth

dataset = CropDataset(root_dir=root_path,
                      csv_file=csv_file,
                      images_per_level=n_images,
                      crop=crop,
                      plants=plant_input,
                      days=days_input,
                      transform=transform)
# Split the dataset into training and validation sets
train_size = int(0.8 * len(dataset))  # 80% for training
val_size = len(dataset) - train_size  # 20% for validation
print(train_size,val_size)
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# DataLoader for training and validation sets
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)



class VisionTransformer(nn.Module):
    def __init__(self, input_channels, patch_size, num_patches, projection_dim, num_heads, num_layers, mlp_dim, num_images, dropout_rate=0.1):
        super(VisionTransformer, self).__init__()

        self.num_images = num_images  # Total number of images (24 images in your case)
        self.patch_size = patch_size
        self.num_patches = num_patches
        self.projection_dim = projection_dim
        self.num_heads = num_heads
        self.num_layers = num_layers
        self.mlp_dim = mlp_dim

        # Separate patch embedding layers for each image (RGB)
        self.patch_embeds = nn.ModuleList([
            nn.Conv2d(input_channels // num_images, projection_dim, kernel_size=patch_size, stride=patch_size)
            for _ in range(num_images)
        ])

        # Positional Encoding (Learnable)
        self.positional_encoding = nn.Parameter(torch.randn(1, num_patches, projection_dim))

        # Transformer Encoder Layers (modified to return attention weights)
        self.attention_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(
                d_model=projection_dim,
                nhead=num_heads,
                dim_feedforward=mlp_dim,
                dropout=dropout_rate,
                batch_first=True
            )
            for _ in range(num_layers)
        ])

        # MLP Head for classification/regression
        self.mlp_head = nn.Sequential(
            nn.Linear(projection_dim * num_images, mlp_dim),
            nn.ReLU(),
            nn.Linear(mlp_dim, 1)
        )

    def forward(self, x):
        batch_size = x.shape[0]

        # Step 1: Patch Embedding (Separate for each image)
        patch_embeddings = []
        for i in range(self.num_images):
            # Split the input channels into separate images (3 channels each for RGB)
            img_x = x[:, i:(i+1), :, :]  # Shape: (batch_size, 3, height, width)
            patch_embed = self.patch_embeds[i](img_x)  # Apply separate embedding
            patch_embed = patch_embed.flatten(2).transpose(1, 2)  # Shape: (batch_size, num_patches, projection_dim)
            patch_embeddings.append(patch_embed)

        # Step 2: Add Positional Encoding
        patch_embeddings = [pe + self.positional_encoding for pe in patch_embeddings]

        # Step 3: Transformer Encoder Layers (Self-attention + Feed Forward)
        attention_weights = []  # To store attention weights
        for layer in self.attention_layers:
            layer_attention_weights = []  # Store the attention weights for each layer
            for i in range(self.num_images):
                # Modified to return attention weights (self-attention)
                attn_output, attn_weights = layer.self_attn(patch_embeddings[i], patch_embeddings[i], patch_embeddings[i])
                patch_embeddings[i] = attn_output
                layer_attention_weights.append(attn_weights)
            attention_weights.append(layer_attention_weights)

        # Step 4: Concatenate the projections from each image (Shape: (batch_size, num_patches, projection_dim * num_images))
        x = torch.cat(patch_embeddings, dim=-1)  # Concatenate across the last dimension (projection_dim)

        # Step 5: Pooling (Take mean across all patches)
        x = x.mean(dim=1)  # Mean pooling over patches (Shape: (batch_size, projection_dim * num_images))

        # Step 6: MLP Head for classification/regression
        output = self.mlp_head(x)

        return output, attention_weights  # Return attention weights too

# Create two independent instances of the model

def create_model():
    return VisionTransformer(input_channels, patch_size, num_patches, projection_dim, num_heads, num_layers, mlp_dim, num_images, dropout_rate)

# Create two independent instances of the model
model = [create_model(), create_model()]

model[0].to(device)
model[1].to(device)
optimizer = [optim.Adam(model[0].parameters(), lr=0.0001), optim.Adam(model[1].parameters(), lr=0.0001)]
criterion = nn.MSELoss()

def train_and_validate(train_loader, val_loader, num_epochs=10):
    train_losses_leaf, train_losses_age, val_losses_leaf, val_losses_age = [], [], [], []
    train_mae_leaf, train_mae_age, val_mae_leaf, val_mae_age = [], [], [], []
    train_r2_leaf, train_r2_age, val_r2_leaf, val_r2_age = [], [], [], []

    for epoch in range(num_epochs):
        # Training Phase
        for i in range(2):
            model[i].train()

        total_loss = [0, 0]
        train_loader_tqdm = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}")
        val_loader_tqdm = tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs}")
        all_preds, all_labels = [[], []], [[], []]
        
        for batch_idx, (images, leaf_labels, age_labels) in enumerate(train_loader_tqdm):
            images, leaf_labels, age_labels = images.to(device), leaf_labels.to(device), age_labels.to(device)
            
            for i in range(2):
                optimizer[i].zero_grad()
                preds, _ = model[i](images)
                loss = criterion(preds.squeeze(), leaf_labels if i == 0 else age_labels)
                loss.backward()
                optimizer[i].step()
                total_loss[i] += loss.item()
                
                all_preds[i].extend(preds.squeeze().cpu().detach().numpy())
                all_labels[i].extend((leaf_labels if i == 0 else age_labels).cpu().numpy())

            train_loader_tqdm.set_postfix({"Leaf RMSE": (total_loss[0]/(batch_idx+1))**0.5, "Age RMSE": (total_loss[1]/(batch_idx+1))**0.5})

        train_losses_leaf.append(total_loss[0]**0.5)
        train_losses_age.append(total_loss[1]**0.5)
        train_mae_leaf.append(mean_absolute_error(all_labels[0], all_preds[0]))
        train_mae_age.append(mean_absolute_error(all_labels[1], all_preds[1]))
        train_r2_leaf.append(r2_score(all_labels[0], all_preds[0]))
        train_r2_age.append(r2_score(all_labels[1], all_preds[1]))

        # Validation Phase
        for i in range(2):
            model[i].eval()

        total_val_loss = [0, 0]
        all_val_preds, all_val_labels = [[], []], [[], []]

        with torch.no_grad():
            for images, leaf_labels, age_labels in val_loader:
                images, leaf_labels, age_labels = images.to(device), leaf_labels.to(device), age_labels.to(device)
                
                for i in range(2):
                    preds, _ = model[i](images)
                    loss = criterion(preds.squeeze(), leaf_labels if i == 0 else age_labels)
                    total_val_loss[i] += loss.item()
                    
                    all_val_preds[i].extend(preds.squeeze().cpu().numpy())
                    all_val_labels[i].extend((leaf_labels if i == 0 else age_labels).cpu().numpy())
                val_loader_tqdm.set_postfix({"Val Leaf RMSE": (total_val_loss[0]/(batch_idx+1))**0.5, "Val Age RMSE": (total_val_loss[1]/(batch_idx+1))**0.5})

        val_losses_leaf.append(total_val_loss[0]**0.5)
        val_losses_age.append(total_val_loss[1]**0.5)
        val_mae_leaf.append(mean_absolute_error(all_val_labels[0], all_val_preds[0]))
        val_mae_age.append(mean_absolute_error(all_val_labels[1], all_val_preds[1]))
        val_r2_leaf.append(r2_score(all_val_labels[0], all_val_preds[0]))
        val_r2_age.append(r2_score(all_val_labels[1], all_val_preds[1]))

        print(f"Epoch {epoch+1}/{num_epochs} - Train MAE Leaf: {train_mae_leaf[-1]:.4f}, Train MAE Age: {train_mae_age[-1]:.4f}, R² Leaf: {train_r2_leaf[-1]:.4f}, R² Age: {train_r2_age[-1]:.4f}")
        print(f"Validation - MAE Leaf: {val_mae_leaf[-1]:.4f}, MAE Age: {val_mae_age[-1]:.4f}, R² Leaf: {val_r2_leaf[-1]:.4f}, R² Age: {val_r2_age[-1]:.4f}")
        torch.save(model[0].state_dict(), f"mustard_vit_leaf_count_{epoch+1}.pth")
        torch.save(model[1].state_dict(), f"mustard_vit_age_prediction_{epoch+1}.pth")

    torch.save(model[0].state_dict(), "mustard_vit_leaf_count.pth")
    torch.save(model[1].state_dict(), "mustard_vit_age_prediction.pth")
    print("Models saved successfully!")

    print("Train Losses Leaf:", train_losses_leaf)
    print("Validation Losses Leaf:", val_losses_leaf)
    print("Train Losses Age:", train_losses_age)
    print("Validation Losses Age:", val_losses_age)
    print(num_epochs)


    plt.figure(figsize=(10,5))
    plt.plot(range(1, num_epochs+1), train_losses_leaf, label='Train Leaf RMSE')
    plt.plot(range(1, num_epochs+1), val_losses_leaf, label='Validation Leaf RMSE')
    plt.xlabel("Epochs")
    plt.ylabel("RMSE")
    plt.legend()
    plt.title("Leaf Count Training and Validation RMSE")
    plt.savefig("leaf_training_validation_rmse.png")
    plt.savefig("leaf_training_validation_rmse.pdf")
    print('1')
    plt.figure(figsize=(10,5))
    plt.plot(range(1, num_epochs+1), train_losses_age, label='Train Age RMSE')
    plt.plot(range(1, num_epochs+1), val_losses_age, label='Validation Age RMSE')
    plt.xlabel("Epochs")
    plt.ylabel("RMSE")
    plt.legend()
    plt.title("Age Prediction Training and Validation RMSE")
    plt.savefig("age_training_validation_rmse.png")
    plt.savefig("age_training_validation_rmse.pdf")
    print("Graphs saved as PNG and PDF!")

train_and_validate(train_loader, val_loader, num_epochs=epochs)
# Out:
# cpu
# multiple_selections: [[0, 90, 180, 270], [15, 105, 195, 285], [30, 120, 210, 300], [45, 135, 225, 315], [60, 150, 240, 330], [75, 165, 255, 345]]
# day directory not found: /home/zaeemy/zaeem/mustard/p1/d12
# day directory not found: /home/zaeemy/zaeem/mustard/p2/d12
# day directory not found: /home/zaeemy/zaeem/mustard/p2/d17
# day directory not found: /home/zaeemy/zaeem/mustard/p2/d19
# Total samples loaded: 2100
# 1680 420
# Epoch 1/10:   0%|                                       | 0/210 [00:00<?, ?it/s]
#
# Epoch 1/10: 100%|█| 210/210 [10:17<00:00,  2.94s/it, Leaf RMSE=10.8, Age RMSE=13
#
#
# Epoch 1/10:   0%| | 0/53 [10:22<?, ?it/s, Val Leaf RMSE=0.608, Val Age RMSE=0.57
#
# Epoch 1/10:   0%|  | 0/53 [10:23<?, ?it/s, Val Leaf RMSE=0.9, Val Age RMSE=1.03]
#
# Epoch 1/10:   0%| | 0/53 [10:24<?, ?it/s, Val Leaf RMSE=1.03, Val Age RMSE=1.29]
#
# Epoch 1/10:   0%|  | 0/53 [10:25<?, ?it/s, Val Leaf RMSE=1.2, Val Age RMSE=1.52]
#
# Epoch 1/10:   0%|  | 0/53 [10:26<?, ?it/s, Val Leaf RMSE=1.35, Val Age RMSE=1.7]
#
# Epoch 1/10:   0%| | 0/53 [10:27<?, ?it/s, Val Leaf RMSE=1.39, Val Age RMSE=1.86]
#
# Epoch 1/10:   0%| | 0/53 [10:28<?, ?it/s, Val Leaf RMSE=1.41, Val Age RMSE=1.95]
#
# Epoch 1/10:   0%|    | 0/53 [10:29<?, ?it/s, Val Leaf RMSE=1.51, Val Age RMSE=2]
#
# Epoch 1/10:   0%| | 0/53 [10:31<?, ?it/s, Val Leaf RMSE=1.57, Val Age RMSE=2.06]
#
# Epoch 1/10:   0%|  | 0/53 [10:32<?, ?it/s, Val Leaf RMSE=1.6, Val Age RMSE=2.12]
#
# Epoch 1/10:   0%| | 0/53 [10:33<?, ?it/s, Val Leaf RMSE=1.72, Val Age RMSE=2.26]
#
# Epoch 1/10:   0%| | 0/53 [10:35<?, ?it/s, Val Leaf RMSE=1.87, Val Age RMSE=2.44]
#
# Epoch 1/10:   0%| | 0/53 [10:36<?, ?it/s, Val Leaf RMSE=1.98, Val Age RMSE=2.52]
#
#
# Epoch 10/10:   0%| | 0/53 [11:11<?, ?it/s, Val Leaf RMSE=2.76, Val Age RMSE=10.4
#
#
# Epoch 10/10:   0%| | 0/53 [11:12<?, ?it/s, Val Leaf RMSE=2.77, Val Age RMSE=10.5
#
#
# Epoch 10/10:   0%| | 0/53 [11:13<?, ?it/s, Val Leaf RMSE=2.77, Val Age RMSE=10.7
#
#
# Epoch 10/10:   0%| | 0/53 [11:13<?, ?it/s, Val Leaf RMSE=2.79, Val Age RMSE=10.7
#
#
# Epoch 10/10:   0%| | 0/53 [11:15<?, ?it/s, Val Leaf RMSE=2.83, Val Age RMSE=10.9
#
#
# Epoch 10/10:   0%| | 0/53 [11:16<?, ?it/s, Val Leaf RMSE=2.83, Val Age RMSE=10.9
#
#
# Epoch 10/10:   0%| | 0/53 [11:17<?, ?it/s, Val Leaf RMSE=2.84, Val Age RMSE=11.1
#
#
# Epoch 10/10:   0%| | 0/53 [11:17<?, ?it/s, Val Leaf RMSE=2.91, Val Age RMSE=11.1
#
#
# Epoch 10/10:   0%| | 0/53 [11:19<?, ?it/s, Val Leaf RMSE=2.94, Val Age RMSE=11.4
#
#
# Epoch 10/10:   0%| | 0/53 [11:20<?, ?it/s, Val Leaf RMSE=2.99, Val Age RMSE=11.4
#
#
# Epoch 10/10:   0%| | 0/53 [11:20<?, ?it/s, Val Leaf RMSE=3.01, Val Age RMSE=11.6
#
#
# Epoch 10/10:   0%| | 0/53 [11:21<?, ?it/s, Val Leaf RMSE=3.03, Val Age RMSE=11.7
#
#
# Epoch 10/10:   0%| | 0/53 [11:21<?, ?it/s, Val Leaf RMSE=3.08, Val Age RMSE=11.8
# Epoch 10/10 - Train MAE Leaf: 3.2941, Train MAE Age: 4.2150, R² Leaf: 0.6884, R² Age: 0.7601
# Validation - MAE Leaf: 4.1471, MAE Age: 15.2131, R² Leaf: 0.4843, R² Age: -3.4531
# Models saved successfully!
# Train Losses Leaf: [155.859874502352, 108.69825837149084, 97.82618381467346, 91.61968909142159, 84.68893132988498, 75.9097065254426, 77.56591290166575, 70.85870293884206, 70.78596643898155, 67.59121609760518]
# Validation Losses Leaf: [58.618726764791894, 50.197046751944306, 48.699044145665965, 44.725883887860725, 43.12200771952445, 42.62741997636856, 39.234829853297086, 37.86198789716844, 39.41036000852745, 44.57030030901489]
# Train Losses Age: [190.8466008362095, 125.89460388842433, 114.21494431946076, 105.60408341557576, 95.36719157501034, 86.15100005560706, 80.4278189606496, 77.48684742900915, 78.75667973602367, 76.97640530628169]
# Validation Losses Age: [77.13021459525133, 54.63790330879807, 56.69442025437006, 57.275318560802916, 66.76944128084111, 103.92146661150798, 191.1085646593986, 146.2526078407379, 191.2184081270117, 171.71929960431908]
# 10
# Epoch 10/10:   0%| | 0/53 [11:22<?, ?it/s, Val Leaf RMSE=3.08, Val Age RMSE=11.8
# 1
# Graphs saved as PNG and PDF!

# %%
## Base model of 3 layers 8 attention heads 
### Canny edge dataset instead of original dataset
### Overfitting occured due to high complexity

# %%
# Canny edge dataset with 3 layers
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import os
from PIL import Image
import random
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score, mean_absolute_error

# Define the device (GPU or CPU)
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(device)
################################# Input here ###################################
root_path='/home/zaeemy/zaeem/'
crop='mustard'
csv_file='/home/zaeemy/zaeem/mustard_train.csv'
n_images=4
epochs=10
plant_input=2
days_input=37
batch_size = 8
seed=42
height, width = 224, 224
# Transformations for resizing and converting to tensor
transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()])
##############################################################################

# Set random seeds for reproducibility
def set_seed(seed=42):
    """
    Set random seeds for Python, NumPy, and PyTorch to ensure reproducibility.
    """
    random.seed(seed)  # Python random seed
    np.random.seed(seed)  # Numpy random seed
    torch.manual_seed(seed)  # PyTorch CPU seed
    torch.cuda.manual_seed(seed)  # PyTorch GPU seed (for CUDA)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU setups

    # Ensure deterministic behavior in CUDA (if using GPU)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Initialize seed for reproducibility
set_seed(42)

num_images = n_images  # Number of images (24 RGB images)
input_channels = num_images*1  # 24 RGB images (3 channels each)
patch_size = 16  # Size of each patch
num_patches = (height // patch_size) * (width // patch_size)  # Number of patches (14 * 14 for 224x224 images)
projection_dim = 256  # Embedding dimension for each patch
num_heads = 8  # Number of attention heads
num_layers = 3  # Number of transformer layers
mlp_dim = 512  # Dimension of the MLP head
num_classes = 1  # Number of output classes (for day or leaf count prediction)
dropout_rate = 0.1  # Dropout rate


class CropDataset(Dataset):
    def __init__(self, root_dir, csv_file, images_per_level, crop, plants, days,
                 levels=['L1', 'L2', 'L3', 'L4', 'L5'], transform=None):
        """
        Args:
            root_dir (str): Directory with all the images.
            csv_file (str): Path to the CSV file containing ground truth (filename, leaf_count, age).
            images_per_level (int): Number of images to select per level (should be factors of 24).
            crop (str): Crop type (e.g., "mustard").
            plants (int): Number of plants (e.g., 4).
            days (int): Number of days (e.g., 59).
            levels (list): List of levels (e.g., ['L1', 'L2', 'L3', 'L4', 'L5']).
            transform (callable, optional): Transform to be applied on a sample.
        """
        self.root_dir = root_dir
        self.csv_file = csv_file
        self.images_per_level = images_per_level
        self.crop = crop
        self.plants_num = plants
        self.max_days = days
        self.levels = levels
        self.transform = transform
        self.image_data = self._load_metadata()
        self.image_paths = self._load_image_paths()

    def _load_metadata(self):
        """Load CSV file into a pandas DataFrame and map filenames to leaf counts and ages."""
        df = pd.read_csv(self.csv_file)
        df["filename"] = df["filename"].astype(str)  # Ensure filenames are strings
        return df.set_index("filename")  # Use filename as the index for quick lookup

    def _select_angles(self):
        """
        Select angles dynamically for a given level.
        """
        images_needed = self.images_per_level
        selected_angles = [i for i in range(0, 360, int(360 / images_needed))]

        initial_angles = [i for i in range(15, selected_angles[1], 15)]
        multiple_selections = [selected_angles]

        for initial_angle in initial_angles:
            selection = [initial_angle]
            while len(selection) < images_needed:
                next_angle = (selection[-1] + int(360 / images_needed)) % 360
                if next_angle not in selection:
                    selection.append(next_angle)
            multiple_selections.append(selection)
        print(f"multiple_selections: {multiple_selections}")
        return multiple_selections

    def _load_image_paths(self):
        """
        Load image paths for all levels and plants based on the selection of angles.
        """
        image_paths = []
        multiple_selections = self._select_angles()

        for plant in range(1, self.plants_num + 1):
            plant_path = os.path.join(self.root_dir, crop, f"p{plant}")
            if not os.path.isdir(plant_path):
                print(f"Plant directory not found: {plant_path}")
                continue
            for day in range(1, self.max_days + 1):
                day_path = os.path.join(self.root_dir, crop, f"p{plant}", f"d{day}")
                if not os.path.isdir(day_path):
                    print(f"day directory not found: {day_path}")
                    continue
                for selected_angles in multiple_selections:
                    for level in self.levels:
                        level_path = os.path.join(self.root_dir,self.crop, f"p{plant}", f"d{day}", level)
                        level_image_paths = [
                            os.path.join(level_path, f"{self.crop}_p{plant}_d{day}_{level}_{angle}.png")
                            for angle in selected_angles
                        ]
                        filename = os.path.join(self.crop,f"p{plant}", f"d{day}", level,f"{self.crop}_p{plant}_d{day}_{level}_{selected_angles[0]}.png")
                        leaf_count = self.image_data.loc[filename, "leaf_count"]
                        # print(level_image_paths)
                        image_paths.append((level_image_paths, leaf_count,day))  # Append day number along with image paths

        print(f"Total samples loaded: {len(image_paths)}")
        # print(f"individual sample size: {len(image_paths[0][0])}")
        return image_paths


    def __len__(self):
        return len(self.image_paths)


    def __getitem__(self, idx):
        """
        Get a batch of images from the dataset corresponding to the angles selected.
        """
        images = []
        leaf_count = self.image_paths[idx][1]
        age = self.image_paths[idx][2]
        # print(leaf_count,age)
        all_images= self.image_paths[idx][0]
        # print("length of all images:", len(all_images))
        for img_path in all_images:  # Get the image paths for this sample
            if os.path.isfile(img_path):
                  level_image = Image.open(img_path)
                  if self.transform:
                      level_image = self.transform(level_image)
                  images.append(level_image)
            else:
                    print(f"Path is not a valid file: {img_path}")

        images = torch.cat(images, dim=0)

        return images, torch.tensor(leaf_count, dtype=torch.float32), torch.tensor(age, dtype=torch.float32)  # Return both images and the corresponding day as ground truth

dataset = CropDataset(root_dir=root_path,
                      csv_file=csv_file,
                      images_per_level=n_images,
                      crop=crop,
                      plants=plant_input,
                      days=days_input,
                      transform=transform)
# Split the dataset into training and validation sets
train_size = int(0.8 * len(dataset))  # 80% for training
val_size = len(dataset) - train_size  # 20% for validation
print(train_size,val_size)
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# DataLoader for training and validation sets
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)



class VisionTransformer(nn.Module):
    def __init__(self, input_channels, patch_size, num_patches, projection_dim, num_heads, num_layers, mlp_dim, num_images, dropout_rate=0.1):
        super(VisionTransformer, self).__init__()

        self.num_images = num_images  # Total number of images (24 images in your case)
        self.patch_size = patch_size
        self.num_patches = num_patches
        self.projection_dim = projection_dim
        self.num_heads = num_heads
        self.num_layers = num_layers
        self.mlp_dim = mlp_dim

        # Separate patch embedding layers for each image (RGB)
        self.patch_embeds = nn.ModuleList([
            nn.Conv2d(input_channels // num_images, projection_dim, kernel_size=patch_size, stride=patch_size)
            for _ in range(num_images)
        ])

        # Positional Encoding (Learnable)
        self.positional_encoding = nn.Parameter(torch.randn(1, num_patches, projection_dim))

        # Transformer Encoder Layers (modified to return attention weights)
        self.attention_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(
                d_model=projection_dim,
                nhead=num_heads,
                dim_feedforward=mlp_dim,
                dropout=dropout_rate,
                batch_first=True
            )
            for _ in range(num_layers)
        ])

        # MLP Head for classification/regression
        self.mlp_head = nn.Sequential(
            nn.Linear(projection_dim * num_images, mlp_dim),
            nn.ReLU(),
            nn.Linear(mlp_dim, 1)
        )

    def forward(self, x):
        batch_size = x.shape[0]

        # Step 1: Patch Embedding (Separate for each image)
        patch_embeddings = []
        for i in range(self.num_images):
            # Split the input channels into separate images (3 channels each for RGB)
            img_x = x[:, i:(i+1), :, :]  # Shape: (batch_size, 3, height, width)
            patch_embed = self.patch_embeds[i](img_x)  # Apply separate embedding
            patch_embed = patch_embed.flatten(2).transpose(1, 2)  # Shape: (batch_size, num_patches, projection_dim)
            patch_embeddings.append(patch_embed)

        # Step 2: Add Positional Encoding
        patch_embeddings = [pe + self.positional_encoding for pe in patch_embeddings]

        # Step 3: Transformer Encoder Layers (Self-attention + Feed Forward)
        attention_weights = []  # To store attention weights
        for layer in self.attention_layers:
            layer_attention_weights = []  # Store the attention weights for each layer
            for i in range(self.num_images):
                # Modified to return attention weights (self-attention)
                attn_output, attn_weights = layer.self_attn(patch_embeddings[i], patch_embeddings[i], patch_embeddings[i])
                patch_embeddings[i] = attn_output
                layer_attention_weights.append(attn_weights)
            attention_weights.append(layer_attention_weights)

        # Step 4: Concatenate the projections from each image (Shape: (batch_size, num_patches, projection_dim * num_images))
        x = torch.cat(patch_embeddings, dim=-1)  # Concatenate across the last dimension (projection_dim)

        # Step 5: Pooling (Take mean across all patches)
        x = x.mean(dim=1)  # Mean pooling over patches (Shape: (batch_size, projection_dim * num_images))

        # Step 6: MLP Head for classification/regression
        output = self.mlp_head(x)

        return output, attention_weights  # Return attention weights too

# Create two independent instances of the model

def create_model():
    return VisionTransformer(input_channels, patch_size, num_patches, projection_dim, num_heads, num_layers, mlp_dim, num_images, dropout_rate)

# Create two independent instances of the model
model = [create_model(), create_model()]

model[0].to(device)
model[1].to(device)
optimizer = [optim.Adam(model[0].parameters(), lr=0.0001), optim.Adam(model[1].parameters(), lr=0.0001)]
criterion = nn.MSELoss()

def train_and_validate(train_loader, val_loader, num_epochs=10):
    train_losses_leaf, train_losses_age, val_losses_leaf, val_losses_age = [], [], [], []
    train_mae_leaf, train_mae_age, val_mae_leaf, val_mae_age = [], [], [], []
    train_r2_leaf, train_r2_age, val_r2_leaf, val_r2_age = [], [], [], []

    for epoch in range(num_epochs):
        # Training Phase
        for i in range(2):
            model[i].train()

        total_loss = [0, 0]
        train_loader_tqdm = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}")
        val_loader_tqdm = tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs}")
        all_preds, all_labels = [[], []], [[], []]
        
        for batch_idx, (images, leaf_labels, age_labels) in enumerate(train_loader_tqdm):
            images, leaf_labels, age_labels = images.to(device), leaf_labels.to(device), age_labels.to(device)
            
            for i in range(2):
                optimizer[i].zero_grad()
                preds, _ = model[i](images)
                loss = criterion(preds.squeeze(), leaf_labels if i == 0 else age_labels)
                loss.backward()
                optimizer[i].step()
                total_loss[i] += loss.item()
                
                all_preds[i].extend(preds.squeeze().cpu().detach().numpy())
                all_labels[i].extend((leaf_labels if i == 0 else age_labels).cpu().numpy())

            train_loader_tqdm.set_postfix({"Leaf RMSE": (total_loss[0]/(batch_idx+1))**0.5, "Age RMSE": (total_loss[1]/(batch_idx+1))**0.5})

        train_losses_leaf.append(total_loss[0]**0.5)
        train_losses_age.append(total_loss[1]**0.5)
        train_mae_leaf.append(mean_absolute_error(all_labels[0], all_preds[0]))
        train_mae_age.append(mean_absolute_error(all_labels[1], all_preds[1]))
        train_r2_leaf.append(r2_score(all_labels[0], all_preds[0]))
        train_r2_age.append(r2_score(all_labels[1], all_preds[1]))

        # Validation Phase
        for i in range(2):
            model[i].eval()

        total_val_loss = [0, 0]
        all_val_preds, all_val_labels = [[], []], [[], []]

        with torch.no_grad():
            for images, leaf_labels, age_labels in val_loader:
                images, leaf_labels, age_labels = images.to(device), leaf_labels.to(device), age_labels.to(device)
                
                for i in range(2):
                    preds, _ = model[i](images)
                    loss = criterion(preds.squeeze(), leaf_labels if i == 0 else age_labels)
                    total_val_loss[i] += loss.item()
                    
                    all_val_preds[i].extend(preds.squeeze().cpu().numpy())
                    all_val_labels[i].extend((leaf_labels if i == 0 else age_labels).cpu().numpy())
                val_loader_tqdm.set_postfix({"Val Leaf RMSE": (total_val_loss[0]/(batch_idx+1))**0.5, "Val Age RMSE": (total_val_loss[1]/(batch_idx+1))**0.5})

        val_losses_leaf.append(total_val_loss[0]**0.5)
        val_losses_age.append(total_val_loss[1]**0.5)
        val_mae_leaf.append(mean_absolute_error(all_val_labels[0], all_val_preds[0]))
        val_mae_age.append(mean_absolute_error(all_val_labels[1], all_val_preds[1]))
        val_r2_leaf.append(r2_score(all_val_labels[0], all_val_preds[0]))
        val_r2_age.append(r2_score(all_val_labels[1], all_val_preds[1]))

        print(f"Epoch {epoch+1}/{num_epochs} - Train MAE Leaf: {train_mae_leaf[-1]:.4f}, Train MAE Age: {train_mae_age[-1]:.4f}, R² Leaf: {train_r2_leaf[-1]:.4f}, R² Age: {train_r2_age[-1]:.4f}")
        print(f"Validation - MAE Leaf: {val_mae_leaf[-1]:.4f}, MAE Age: {val_mae_age[-1]:.4f}, R² Leaf: {val_r2_leaf[-1]:.4f}, R² Age: {val_r2_age[-1]:.4f}")
        torch.save(model[0].state_dict(), f"mustard_vit_leaf_count_{epoch+1}.pth")
        torch.save(model[1].state_dict(), f"mustard_vit_age_prediction_{epoch+1}.pth")

    torch.save(model[0].state_dict(), "3_layer_mustard_vit_leaf_count.pth")
    torch.save(model[1].state_dict(), "3_layer_mustard_vit_age_prediction.pth")
    print("Models saved successfully!")

    print("Train Losses Leaf:", train_losses_leaf)
    print("Validation Losses Leaf:", val_losses_leaf)
    print("Train Losses Age:", train_losses_age)
    print("Validation Losses Age:", val_losses_age)
    print(num_epochs)


    plt.figure(figsize=(10,5))
    plt.plot(range(1, num_epochs+1), train_losses_leaf, label='Train Leaf RMSE')
    plt.plot(range(1, num_epochs+1), val_losses_leaf, label='Validation Leaf RMSE')
    plt.xlabel("Epochs")
    plt.ylabel("RMSE")
    plt.legend()
    plt.title("Leaf Count Training and Validation RMSE")
    plt.savefig("3_layer_leaf_training_validation_rmse.png")
    plt.savefig("3_layer_leaf_training_validation_rmse.pdf")
    print('1')
    plt.figure(figsize=(10,5))
    plt.plot(range(1, num_epochs+1), train_losses_age, label='Train Age RMSE')
    plt.plot(range(1, num_epochs+1), val_losses_age, label='Validation Age RMSE')
    plt.xlabel("Epochs")
    plt.ylabel("RMSE")
    plt.legend()
    plt.title("Age Prediction Training and Validation RMSE")
    plt.savefig("3_layer_age_training_validation_rmse.png")
    plt.savefig("3_layer_age_training_validation_rmse.pdf")
    print("Graphs saved as PNG and PDF!")

train_and_validate(train_loader, val_loader, num_epochs=epochs)
# Out:
# cpu
# multiple_selections: [[0, 90, 180, 270], [15, 105, 195, 285], [30, 120, 210, 300], [45, 135, 225, 315], [60, 150, 240, 330], [75, 165, 255, 345]]
# day directory not found: /home/zaeemy/zaeem/mustard/p1/d12
# day directory not found: /home/zaeemy/zaeem/mustard/p2/d12
# day directory not found: /home/zaeemy/zaeem/mustard/p2/d17
# day directory not found: /home/zaeemy/zaeem/mustard/p2/d19
# Total samples loaded: 2100
# 1680 420
# Epoch 1/10:   0%|                                       | 0/210 [00:00<?, ?it/s]
#
# Epoch 1/10: 100%|█| 210/210 [05:40<00:00,  1.62s/it, Leaf RMSE=11.1, Age RMSE=13
#
#
# Epoch 1/10:   0%| | 0/53 [05:44<?, ?it/s, Val Leaf RMSE=0.61, Val Age RMSE=0.664
#
# Epoch 1/10:   0%| | 0/53 [05:44<?, ?it/s, Val Leaf RMSE=0.901, Val Age RMSE=1.04
#
# Epoch 1/10:   0%| | 0/53 [05:44<?, ?it/s, Val Leaf RMSE=1.02, Val Age RMSE=1.32]
#
# Epoch 1/10:   0%|   | 0/53 [05:45<?, ?it/s, Val Leaf RMSE=1.2, Val Age RMSE=1.5]
#
# Epoch 1/10:   0%| | 0/53 [05:48<?, ?it/s, Val Leaf RMSE=1.34, Val Age RMSE=1.66]
#
# Epoch 1/10:   0%| | 0/53 [05:48<?, ?it/s, Val Leaf RMSE=1.38, Val Age RMSE=1.82]
#
# Epoch 1/10:   0%| | 0/53 [05:49<?, ?it/s, Val Leaf RMSE=1.41, Val Age RMSE=1.95]
#
# Epoch 1/10:   0%| | 0/53 [05:50<?, ?it/s, Val Leaf RMSE=1.51, Val Age RMSE=2.02]
#
# Epoch 1/10:   0%| | 0/53 [05:52<?, ?it/s, Val Leaf RMSE=1.56, Val Age RMSE=2.08]
#
# Epoch 1/10:   0%|  | 0/53 [05:52<?, ?it/s, Val Leaf RMSE=1.6, Val Age RMSE=2.15]
#
# Epoch 1/10:   0%| | 0/53 [05:53<?, ?it/s, Val Leaf RMSE=1.72, Val Age RMSE=2.28]
#
# Epoch 1/10:   0%| | 0/53 [05:53<?, ?it/s, Val Leaf RMSE=1.87, Val Age RMSE=2.42]
#
# Epoch 1/10:   0%|  | 0/53 [05:55<?, ?it/s, Val Leaf RMSE=1.97, Val Age RMSE=2.5]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:13<?, ?it/s, Val Leaf RMSE=1.39, Val Age RMSE=1.5]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:14<?, ?it/s, Val Leaf RMSE=1.4, Val Age RMSE=1.53]
#
#
# Epoch 6/10:   0%| | 0/53 [06:16<?, ?it/s, Val Leaf RMSE=1.48, Val Age RMSE=1.56]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:16<?, ?it/s, Val Leaf RMSE=1.51, Val Age RMSE=1.6]
#
#
# Epoch 6/10:   0%| | 0/53 [06:17<?, ?it/s, Val Leaf RMSE=1.52, Val Age RMSE=1.63]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:17<?, ?it/s, Val Leaf RMSE=1.56, Val Age RMSE=1.7]
#
#
# Epoch 6/10:   0%| | 0/53 [06:19<?, ?it/s, Val Leaf RMSE=1.58, Val Age RMSE=1.76]
#
#
# Epoch 6/10:   0%|   | 0/53 [06:20<?, ?it/s, Val Leaf RMSE=1.6, Val Age RMSE=1.8]
#
#
# Epoch 6/10:   0%| | 0/53 [06:21<?, ?it/s, Val Leaf RMSE=1.63, Val Age RMSE=1.83]
#
#
# Epoch 6/10:   0%| | 0/53 [06:22<?, ?it/s, Val Leaf RMSE=1.66, Val Age RMSE=1.89]
#
#
# Epoch 6/10:   0%| | 0/53 [06:24<?, ?it/s, Val Leaf RMSE=1.69, Val Age RMSE=1.93]
#
#
# Epoch 6/10:   0%| | 0/53 [06:25<?, ?it/s, Val Leaf RMSE=1.73, Val Age RMSE=1.97]
#
#
# Epoch 6/10:   0%| | 0/53 [06:25<?, ?it/s, Val Leaf RMSE=1.76, Val Age RMSE=2.02]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:26<?, ?it/s, Val Leaf RMSE=1.8, Val Age RMSE=2.07]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:27<?, ?it/s, Val Leaf RMSE=1.87, Val Age RMSE=2.1]
#
#
# Epoch 6/10:   0%| | 0/53 [06:28<?, ?it/s, Val Leaf RMSE=1.88, Val Age RMSE=2.14]
#
#
# Epoch 6/10:   0%| | 0/53 [06:28<?, ?it/s, Val Leaf RMSE=1.93, Val Age RMSE=2.16]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:29<?, ?it/s, Val Leaf RMSE=1.95, Val Age RMSE=2.2]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:31<?, ?it/s, Val Leaf RMSE=1.98, Val Age RMSE=2.3]
#
#
# Epoch 6/10:   0%|    | 0/53 [06:32<?, ?it/s, Val Leaf RMSE=2, Val Age RMSE=2.33]
#
#
# Epoch 6/10:   0%| | 0/53 [06:32<?, ?it/s, Val Leaf RMSE=2.02, Val Age RMSE=2.36]
#
#
# Epoch 6/10:   0%|  | 0/53 [06:33<?, ?it/s, Val Leaf RMSE=2.11, Val Age RMSE=2.4]
#
#
# Epoch 6/10:   0%| | 0/53 [06:35<?, ?it/s, Val Leaf RMSE=2.16, Val Age RMSE=2.42]
#
# Epoch 7/10:   0%| | 0/53 [07:00<?, ?it/s, Val Leaf RMSE=2.54, Val Age RMSE=2.35]
#
# Epoch 7/10:   0%|  | 0/53 [07:02<?, ?it/s, Val Leaf RMSE=2.58, Val Age RMSE=2.4]
#
# Epoch 7/10:   0%| | 0/53 [07:03<?, ?it/s, Val Leaf RMSE=2.62, Val Age RMSE=2.41]
#
# Epoch 7/10:   0%| | 0/53 [07:03<?, ?it/s, Val Leaf RMSE=2.64, Val Age RMSE=2.42]
#
# Epoch 7/10:   0%| | 0/53 [07:04<?, ?it/s, Val Leaf RMSE=2.65, Val Age RMSE=2.44]
#
# Epoch 7/10:   0%| | 0/53 [07:04<?, ?it/s, Val Leaf RMSE=2.72, Val Age RMSE=2.44]
# Epoch 7/10 - Train MAE Leaf: 3.8650, Train MAE Age: 3.3512, R² Leaf: 0.5842, R² Age: 0.8454
# Validation - MAE Leaf: 3.3853, MAE Age: 4.0233, R² Leaf: 0.6006, R² Age: 0.8089
# Epoch 8/10:   0%|                                       | 0/210 [00:00<?, ?it/s]
#
#
# Epoch 7/10:   0%| | 0/53 [07:04<?, ?it/s, Val Leaf RMSE=2.72, Val Age RMSE=2.44]
# Epoch 8/10: 100%|█| 210/210 [06:18<00:00,  1.80s/it, Leaf RMSE=5.08, Age RMSE=4.
#
#
#
# Epoch 8/10:   0%| | 0/53 [06:21<?, ?it/s, Val Leaf RMSE=0.573, Val Age RMSE=0.4]
#
#
# Epoch 8/10:   0%| | 0/53 [06:22<?, ?it/s, Val Leaf RMSE=0.798, Val Age RMSE=0.49
#
#
# Epoch 8/10:   0%| | 0/53 [06:23<?, ?it/s, Val Leaf RMSE=0.838, Val Age RMSE=0.67
#
#
# Epoch 8/10:   0%| | 0/53 [06:23<?, ?it/s, Val Leaf RMSE=0.943, Val Age RMSE=0.72
#
#
# Epoch 8/10:   0%| | 0/53 [06:25<?, ?it/s, Val Leaf RMSE=0.967, Val Age RMSE=0.8]
#
#
# Epoch 8/10:   0%| | 0/53 [06:25<?, ?it/s, Val Leaf RMSE=0.984, Val Age RMSE=0.83
#
#
# Epoch 8/10:   0%| | 0/53 [06:26<?, ?it/s, Val Leaf RMSE=1.02, Val Age RMSE=0.985
#
#
# Epoch 8/10:   0%| | 0/53 [06:27<?, ?it/s, Val Leaf RMSE=1.09, Val Age RMSE=1.02]
#
#
# Epoch 8/10:   0%|  | 0/53 [06:28<?, ?it/s, Val Leaf RMSE=1.16, Val Age RMSE=1.1]
#
#
# Epoch 8/10:   0%| | 0/53 [06:29<?, ?it/s, Val Leaf RMSE=1.17, Val Age RMSE=1.16]
#
#
# Epoch 8/10:   0%| | 0/53 [06:30<?, ?it/s, Val Leaf RMSE=1.26, Val Age RMSE=1.19]
#
#
# Epoch 8/10:   0%| | 0/53 [06:30<?, ?it/s, Val Leaf RMSE=1.28, Val Age RMSE=1.21]
#
#
# Epoch 8/10:   0%| | 0/53 [06:33<?, ?it/s, Val Leaf RMSE=1.39, Val Age RMSE=1.23]
#
#
# Epoch 8/10:   0%| | 0/53 [06:34<?, ?it/s, Val Leaf RMSE=1.41, Val Age RMSE=1.27]
#
#
# Epoch 8/10:   0%| | 0/53 [06:35<?, ?it/s, Val Leaf RMSE=1.43, Val Age RMSE=1.31]
#
#
# Epoch 8/10:   0%| | 0/53 [06:35<?, ?it/s, Val Leaf RMSE=1.46, Val Age RMSE=1.36]
#
#
# Epoch 8/10:   0%| | 0/53 [06:37<?, ?it/s, Val Leaf RMSE=1.46, Val Age RMSE=1.41]
#
#
# Epoch 8/10:   0%| | 0/53 [06:38<?, ?it/s, Val Leaf RMSE=1.48, Val Age RMSE=1.44]
#
#
# Epoch 8/10:   0%|  | 0/53 [06:38<?, ?it/s, Val Leaf RMSE=1.5, Val Age RMSE=1.47]
#
#
# Epoch 8/10:   0%| | 0/53 [06:39<?, ?it/s, Val Leaf RMSE=1.52, Val Age RMSE=1.52]
#
#
# Epoch 8/10:   0%| | 0/53 [06:41<?, ?it/s, Val Leaf RMSE=1.55, Val Age RMSE=1.56]
#
#
# Epoch 8/10:   0%| | 0/53 [06:41<?, ?it/s, Val Leaf RMSE=1.58, Val Age RMSE=1.59]
#
#
# Epoch 8/10:   0%|  | 0/53 [06:42<?, ?it/s, Val Leaf RMSE=1.6, Val Age RMSE=1.63]
#
#
# Epoch 8/10:   0%| | 0/53 [06:42<?, ?it/s, Val Leaf RMSE=1.65, Val Age RMSE=1.67]
#
#
# Epoch 8/10:   0%|  | 0/53 [06:44<?, ?it/s, Val Leaf RMSE=1.73, Val Age RMSE=1.7]
#
#
# Epoch 8/10:   0%| | 0/53 [06:45<?, ?it/s, Val Leaf RMSE=1.75, Val Age RMSE=1.73]
#
#
# Epoch 8/10:   0%|  | 0/53 [06:45<?, ?it/s, Val Leaf RMSE=1.8, Val Age RMSE=1.75]
#
#
# Epoch 8/10:   0%| | 0/53 [06:46<?, ?it/s, Val Leaf RMSE=1.82, Val Age RMSE=1.78]
#
#
# Epoch 8/10:   0%| | 0/53 [06:48<?, ?it/s, Val Leaf RMSE=1.84, Val Age RMSE=1.84]
#
#
# Epoch 8/10:   0%| | 0/53 [06:48<?, ?it/s, Val Leaf RMSE=1.85, Val Age RMSE=1.88]
#
#
# Epoch 8/10:   0%|  | 0/53 [06:49<?, ?it/s, Val Leaf RMSE=1.86, Val Age RMSE=1.9]
#
#
# Epoch 8/10:   0%| | 0/53 [06:49<?, ?it/s, Val Leaf RMSE=1.94, Val Age RMSE=1.93]
#
#
# Epoch 8/10:   0%|    | 0/53 [06:51<?, ?it/s, Val Leaf RMSE=2, Val Age RMSE=1.95]
#
#
# Epoch 8/10:   0%| | 0/53 [06:52<?, ?it/s, Val Leaf RMSE=2.09, Val Age RMSE=1.98]
#
#
# Epoch 8/10:   0%| | 0/53 [06:52<?, ?it/s, Val Leaf RMSE=2.12, Val Age RMSE=2.03]
#
#
# Epoch 8/10:   0%| | 0/53 [06:53<?, ?it/s, Val Leaf RMSE=2.13, Val Age RMSE=2.05]
#
#
# Epoch 9/10:   0%| | 0/53 [07:09<?, ?it/s, Val Leaf RMSE=2.95, Val Age RMSE=2.06]
#
# Epoch 9/10:   0%| | 0/53 [07:09<?, ?it/s, Val Leaf RMSE=2.96, Val Age RMSE=2.07]
#
# Epoch 9/10:   0%| | 0/53 [07:09<?, ?it/s, Val Leaf RMSE=3.01, Val Age RMSE=2.07]
# Epoch 9/10 - Train MAE Leaf: 3.4688, Train MAE Age: 3.1496, R² Leaf: 0.6502, R² Age: 0.8617
# Validation - MAE Leaf: 4.5057, MAE Age: 3.2654, R² Leaf: 0.5072, R² Age: 0.8627
# Epoch 10/10:   0%|                                      | 0/210 [00:00<?, ?it/s]
#
#
# Epoch 9/10:   0%| | 0/53 [07:09<?, ?it/s, Val Leaf RMSE=3.01, Val Age RMSE=2.07]
# Epoch 10/10: 100%|█| 210/210 [06:32<00:00,  1.87s/it, Leaf RMSE=4.91, Age RMSE=4
#
#
#
# Epoch 10/10:   0%| | 0/53 [06:35<?, ?it/s, Val Leaf RMSE=0.67, Val Age RMSE=0.32
#
#
# Epoch 10/10:   0%| | 0/53 [06:36<?, ?it/s, Val Leaf RMSE=0.929, Val Age RMSE=0.3
#
#
# Epoch 10/10:   0%| | 0/53 [06:36<?, ?it/s, Val Leaf RMSE=0.955, Val Age RMSE=0.5
#
#
# Epoch 10/10:   0%| | 0/53 [06:37<?, ?it/s, Val Leaf RMSE=1.04, Val Age RMSE=0.61
#
#
# Epoch 10/10:   0%| | 0/53 [06:39<?, ?it/s, Val Leaf RMSE=1.06, Val Age RMSE=0.69
#
#
# Epoch 10/10:   0%| | 0/53 [06:40<?, ?it/s, Val Leaf RMSE=1.09, Val Age RMSE=0.71
#
#
# Epoch 10/10:   0%| | 0/53 [06:40<?, ?it/s, Val Leaf RMSE=1.13, Val Age RMSE=0.85
#
#
# Epoch 10/10:   0%| | 0/53 [06:41<?, ?it/s, Val Leaf RMSE=1.19, Val Age RMSE=0.88
#
#
# Epoch 10/10:   0%| | 0/53 [06:43<?, ?it/s, Val Leaf RMSE=1.24, Val Age RMSE=0.97
#
#
# Epoch 10/10:   0%| | 0/53 [06:43<?, ?it/s, Val Leaf RMSE=1.25, Val Age RMSE=1.03
#
#
# Epoch 10/10:   0%| | 0/53 [06:44<?, ?it/s, Val Leaf RMSE=1.37, Val Age RMSE=1.04
#
#
# Epoch 10/10:   0%| | 0/53 [06:44<?, ?it/s, Val Leaf RMSE=1.37, Val Age RMSE=1.06
#
#
# Epoch 10/10:   0%| | 0/53 [06:46<?, ?it/s, Val Leaf RMSE=1.48, Val Age RMSE=1.08
#
#
# Epoch 10/10:   0%| | 0/53 [06:47<?, ?it/s, Val Leaf RMSE=1.52, Val Age RMSE=1.12
#
#
# Epoch 10/10:   0%| | 0/53 [06:47<?, ?it/s, Val Leaf RMSE=1.53, Val Age RMSE=1.16
#
#
# Epoch 10/10:   0%| | 0/53 [06:48<?, ?it/s, Val Leaf RMSE=1.56, Val Age RMSE=1.22
#
#
# Epoch 10/10:   0%| | 0/53 [06:50<?, ?it/s, Val Leaf RMSE=1.57, Val Age RMSE=1.26
#
#
# Epoch 10/10:   0%| | 0/53 [06:50<?, ?it/s, Val Leaf RMSE=1.59, Val Age RMSE=1.28
#
#
# Epoch 10/10:   0%| | 0/53 [06:51<?, ?it/s, Val Leaf RMSE=1.6, Val Age RMSE=1.31]
#
#
# Epoch 10/10:   0%| | 0/53 [06:52<?, ?it/s, Val Leaf RMSE=1.62, Val Age RMSE=1.37
#
#
# Epoch 10/10:   0%| | 0/53 [06:53<?, ?it/s, Val Leaf RMSE=1.64, Val Age RMSE=1.4]
#
#
# Epoch 10/10:   0%| | 0/53 [06:54<?, ?it/s, Val Leaf RMSE=1.67, Val Age RMSE=1.44
#
#
# Epoch 10/10:   0%| | 0/53 [06:54<?, ?it/s, Val Leaf RMSE=1.68, Val Age RMSE=1.48
#
#
# Epoch 10/10:   0%| | 0/53 [06:55<?, ?it/s, Val Leaf RMSE=1.73, Val Age RMSE=1.51
#
#
# Epoch 10/10:   0%| | 0/53 [06:57<?, ?it/s, Val Leaf RMSE=1.81, Val Age RMSE=1.54
#
#
# Epoch 10/10:   0%| | 0/53 [06:57<?, ?it/s, Val Leaf RMSE=1.82, Val Age RMSE=1.58
#
#
# Epoch 10/10:   0%| | 0/53 [06:58<?, ?it/s, Val Leaf RMSE=1.85, Val Age RMSE=1.62
#
#
# Epoch 10/10:   0%| | 0/53 [06:58<?, ?it/s, Val Leaf RMSE=1.87, Val Age RMSE=1.64
#
#
# Epoch 10/10:   0%| | 0/53 [07:01<?, ?it/s, Val Leaf RMSE=1.89, Val Age RMSE=1.68
#
#
# Epoch 10/10:   0%| | 0/53 [07:01<?, ?it/s, Val Leaf RMSE=1.9, Val Age RMSE=1.71]
#
#
# Epoch 10/10:   0%| | 0/53 [07:02<?, ?it/s, Val Leaf RMSE=1.92, Val Age RMSE=1.73
#
#
# Epoch 10/10:   0%| | 0/53 [07:02<?, ?it/s, Val Leaf RMSE=2.01, Val Age RMSE=1.75
#
#
# Epoch 10/10:   0%| | 0/53 [07:04<?, ?it/s, Val Leaf RMSE=2.08, Val Age RMSE=1.76
#
#
# Epoch 10/10:   0%| | 0/53 [07:05<?, ?it/s, Val Leaf RMSE=2.18, Val Age RMSE=1.78
#
#
# Epoch 10/10:   0%| | 0/53 [07:05<?, ?it/s, Val Leaf RMSE=2.23, Val Age RMSE=1.82
#
#
# Epoch 10/10:   0%| | 0/53 [07:06<?, ?it/s, Val Leaf RMSE=2.24, Val Age RMSE=1.84
#
#
# Epoch 10/10:   0%| | 0/53 [07:08<?, ?it/s, Val Leaf RMSE=2.24, Val Age RMSE=1.86
#
#
# Epoch 10/10:   0%| | 0/53 [07:08<?, ?it/s, Val Leaf RMSE=2.32, Val Age RMSE=1.9]
#
#
# Epoch 10/10:   0%| | 0/53 [07:09<?, ?it/s, Val Leaf RMSE=2.33, Val Age RMSE=1.93
#
#
